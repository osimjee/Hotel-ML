# %%
import pandas as pd
hotel_data = pd.read_csv("C:/Users/Omar.Simjee/Downloads/hotel-booking-demand/hotel_bookings.csv")
#I want to create a machine learning model that will identify whther a booking will be cancelled or not

# %%
hotel_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
from sklearn import preprocessing
display(hotel_data['hotel'].unique())
display(hotel_data['arrival_date_month'].unique())
display(hotel_data['meal'].unique())
display(hotel_data['country'].unique())
display(hotel_data['market_segment'].unique())
display(hotel_data['distribution_channel'].unique())
display(hotel_data['reserved_room_type'].unique())
display(hotel_data['assigned_room_type'].unique())
display(hotel_data['deposit_type'].unique())
display(hotel_data['customer_type'].unique())
display(hotel_data['reservation_status'].unique())
display(hotel_data['reservation_status_date'].unique())
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
# ...

# %%
hotel_data = hotel_data.drop(['reservation_status_date'], axis = 1)
#drop this column because it corresponds to a specific date in time that can't really tell you about a future date

# %%
#changing string values into ints
le = preprocessing.LabelEncoder()
hotel_data['hotel'] = le.fit_transform(hotel_data['hotel'])

# %%
hotel_data.head()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0      1            0        342               2015               July
# 1      1            0        737               2015               July
# 2      1            0          7               2015               July
# 3      1            0         13               2015               July
# 4      1            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# ...

# %%
hotel_data['arrival_date_month'] = le.fit_transform(hotel_data['arrival_date_month'])

# %%
hotel_data['meal'] = le.fit_transform(hotel_data['meal'])

# %%
hotel_data['market_segment'] = le.fit_transform(hotel_data['market_segment'])

# %%
hotel_data['distribution_channel'] = le.fit_transform(hotel_data['distribution_channel'])

# %%
hotel_data['reserved_room_type'] = le.fit_transform(hotel_data['reserved_room_type'])

# %%
hotel_data['assigned_room_type'] = le.fit_transform(hotel_data['assigned_room_type'])

# %%
hotel_data['deposit_type'] = le.fit_transform(hotel_data['deposit_type'])

# %%
hotel_data['customer_type'] = le.fit_transform(hotel_data['customer_type'])

# %%
hotel_data['reservation_status'] = le.fit_transform(hotel_data['reservation_status'])

# %%
#country doesn't want to convert for whatever reason so I'm going to remove it for the time being
hotel_data = hotel_data.drop(['country'], axis = 1)
hotel_data = hotel_data.drop(['agent'], axis = 1)
hotel_data = hotel_data.drop(['company'], axis = 1)
#agent and company have a ton of NA values

# %%
from sklearn.model_selection import train_test_split

# %%
#drop all rows that have na values
hotel_data = hotel_data.apply (pd.to_numeric, errors='coerce')
hotel_data = hotel_data.dropna()

print (hotel_data)
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0           1            0        342               2015                   5
# 1           1            0        737               2015                   5
# 2           1            0          7               2015                   5
# 3           1            0         13               2015                   5
# 4           1            0         14               2015                   5
# ...       ...          ...        ...                ...                 ...
# 119385      0            0         23               2017                   1
# 119386      0            0        102               2017                   1
# 119387      0            0         34               2017                   1
# 119388      0            0        109               2017                   1
# 119389      0            0        205               2017                   1
#
# ...

# %%
#both of these come as floats and the model doesn't like that so switching them both to integers
hotel_data['children'] = pd.to_numeric(hotel_data['children'], downcast = 'integer')
hotel_data['adr'] = hotel_data['adr'].astype(int)

# %%
data = hotel_data.drop(['reservation_status'],axis = 1)

# %%
target = hotel_data['reservation_status']

# %%
data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.30, random_state = 10)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gnb = GaussianNB()

pred = gnb.fit(data_train, target_train).predict(data_test)

print("Naive-Bayes accuracy : ",accuracy_score(target_test, pred, normalize = True))
# Out:
# Naive-Bayes accuracy :  0.786324547688184

# %%
from sklearn.svm import LinearSVC
svc_model = LinearSVC(random_state=0, dual = False)
pred = svc_model.fit(data_train, target_train).predict(data_test)
print("LinearSVC accuracy : ",accuracy_score(target_test, pred, normalize = True))
# Out:
# LinearSVC accuracy :  0.9896135805226715
